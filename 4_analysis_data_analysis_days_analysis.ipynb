# %% [markdown]
# ### Гипотеза
#
# Посмотреть как влияет рассматриваемые временные окна неделя, 2 недели и месяц

# %%
import pandas as pd
import numpy as np
import plotly.express as px

# %%
from IPython.core.display import display, HTML, clear_output
display(HTML("<style>.container { width:85% !important; }</style>"))
display(HTML("<style>.prompt { min-width:10ex !important; }</style>"))
pd.set_option('display.max_rows', 1000)
pd.set_option('display.max_columns', 1000)
pd.set_option('display.float_format', lambda x: '%.6f' % x)
# Out:
# /tmp/ipykernel_25936/437858164.py:1: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML, clear_output
# /tmp/ipykernel_25936/437858164.py:1: DeprecationWarning: Importing clear_output from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML, clear_output
# <style>.container { width:85% !important; }</style>
# <style>.prompt { min-width:10ex !important; }</style>

# %%
df_train = pd.read_parquet('../data/train_dataset_hackaton2023_train.gzip')
df_test = pd.read_parquet('../data/hackaton2023_test.gzip')

# %%
df_train.shape[0]
# Out:
# 12129384

# %%
ids_cols = ['customer_id', 'buy_post', 'startdatetime']

# %%
df_train.describe()
# Out:
#           customer_id  date_diff_post        buy_post         revenue  \
# count 12129384.000000  9660867.000000 12129384.000000 12129384.000000
# mean  19809542.263361       20.480386        0.796485      106.799476
# min      29891.000000        0.000000        0.000000        0.010000
# 25%   10108525.000000        8.000000        1.000000       44.990000
# 50%   21274586.000000       17.000000        1.000000       79.980000
# 75%   28038562.000000       30.000000        1.000000      131.772500
# max   46661804.000000       60.000000        1.000000    14499.710000
# std   11389040.436254       15.270910        0.402613      107.438512
#
#                     startdatetime  ownareaall_sqm
# count                    12129384 12129384.000000
# mean   2023-02-20 12:19:13.394691      215.513003
# min           2022-09-02 00:00:39        0.000000
# 25%           2022-12-06 16:12:06      104.900000
# 50%           2023-02-22 11:04:22      210.400000
# 75%           2023-05-09 18:48:02      300.000000
# max           2023-08-01 23:57:46      978.700000
# std                           NaN      122.590689

# %% [markdown]
# Схлопнуть до одного чека для каждого клиента

# %%
df_sum_agg = df_train.groupby(ids_cols, as_index=True).agg({"revenue": ["sum", "count"]})
df_sum_agg.columns = ["revenue_sum", "items_count"]
df_sum_agg.reset_index(inplace=True)

# %%
df_times = df_sum_agg.groupby("customer_id", as_index=False).agg({"startdatetime": ["min", "max"]})
df_times.columns = ["customer_id", "startdatetime_min", "startdatetime_max"]

# %%
df_times['delta_days'] = (df_times['startdatetime_max'] - df_times['startdatetime_min']) / np.timedelta64(1, 's') / 60 / 60 /24

# %%
df_times.describe(percentiles=[i / 10 for i in range(1, 11)] + [0.95, 0.97, 0.99])
# Out:
#           customer_id           startdatetime_min           startdatetime_max  \
# count   500000.000000                      500000                      500000
# mean  20246346.095608  2023-01-30 02:38:34.249616  2023-03-04 15:28:05.646236
# min      29891.000000         2022-09-02 00:00:39         2022-09-02 00:05:28
# 10%    4015495.600000  2022-10-03 15:33:00.500000  2022-10-31 12:38:09.300000
# 20%    8634336.400000  2022-11-03 14:13:11.800000  2022-11-30 14:45:51.400000
# 30%   12046489.400000  2022-12-04 12:06:39.200000         2022-12-30 17:55:43
# 40%   18298842.800000  2023-01-02 17:22:14.200000  2023-01-30 18:57:00.400000
# 50%   21725643.000000  2023-02-01 18:15:01.500000  2023-02-28 17:46:36.500000
# 60%   24118279.600000  2023-03-03 17:46:06.800000  2023-03-31 20:18:55.800000
# 70%   26967157.300000  2023-04-03 13:34:39.900000  2023-04-30 19:09:52.400000
# 80%   29711528.600000  2023-05-03 18:09:15.200000  2023-05-31 20:41:15.200000
# 90%   35856374.400000  2023-06-03 14:15:58.300000  2023-06-30 18:21:27.400000
# 95%   39305812.100000  2023-06-12 19:06:47.050000  2023-07-23 13:48:32.200000
# 97%   41316062.370000  2023-06-20 09:41:51.980000  2023-07-28 16:05:05.210000
# 99%   44072391.110000  2023-07-05 06:25:01.770000  2023-07-31 18:43:21.060000
# 100%  46661804.000000         2023-08-01 21:48:24         2023-08-01 23:57:46
# max   46661804.000000         2023-08-01 21:48:24         2023-08-01 23:57:46
# std   11496610.350691                         NaN                         NaN
#
#          delta_days
# count 500000.000000
# mean      33.534391
# min        0.000231
# 10%        9.972993
# 20%       18.003245
# 30%       24.665043
# 40%       30.053190
# 50%       35.119381
# 60%       40.101292
# 70%       44.734309
# 80%       49.022359
# 90%       53.908176
# 95%       56.108362
# 97%       57.268300
# 99%       59.053993
# 100%      60.973843
# max       60.973843
# std       15.962844

# %% [markdown]
# Рассмотрим окна 7, 14, 28 дней

# %%
def calculate_window_features(dataset, ids_cols, windows):
    df_sum_agg = dataset.groupby(ids_cols, as_index=True).agg({"revenue": ["sum", "count"]})
    df_sum_agg.columns = ["revenue_sum", "items_count"]
    df_sum_agg.reset_index(inplace=True)
    
    df_max_dt = df_sum_agg.groupby(['customer_id'], as_index=False).agg({"startdatetime": ["max"]})
    df_max_dt.columns = ["customer_id", "max_startdatetime"]
    df_sum_agg = df_sum_agg.merge(df_max_dt, on="customer_id", how='inner')
    df_sum_agg['delta_days'] = (df_sum_agg['max_startdatetime'] - df_sum_agg['startdatetime']) / np.timedelta64(1, 's') / 60 / 60 / 24
    
    new_ids_cols = list(set(ids_cols).difference(["startdatetime"]))
    agg_dfs = []
    for window in windows:
        filtered_df = df_sum_agg[df_sum_agg['delta_days'] < 30]
        filtered_df = (
            filtered_df
            .groupby(new_ids_cols, as_index=False)
            .agg({
                "revenue_sum": ["max", "mean", "std", "sum", "count"], 
                "items_count": ["max", "mean", "std", "sum"], 
            })
        )
        filtered_df.columns = new_ids_cols + [
            f"{col}_{agg_func}_{window}d" for col in ["revenue_sum", "items_count"]
            for agg_func in ["max", "mean", "std", "sum", "count"]
        ][:-1]
        agg_dfs.append(filtered_df)
    ids_df = df_sum_agg[new_ids_cols].drop_duplicates().reset_index(drop=True)
    for temp_df in agg_dfs:
        ids_df = ids_df.merge(temp_df, on=new_ids_cols, how='left')
    return ids_df

# %%
windows = [7, 14, 28]

# %%
df_windows_agg = calculate_window_features(df_train, ['customer_id', 'buy_post', 'startdatetime'], windows)

# %%
df_windows_agg.describe()
# Out:
#            buy_post     customer_id  revenue_sum_max_7d  revenue_sum_mean_7d  \
# count 500000.000000   500000.000000       500000.000000        500000.000000
# mean       0.718190 20246346.095608          757.652491           494.607167
# std        0.449882 11496610.350691          495.770731           317.598032
# min        0.000000    29891.000000            1.000000             1.000000
# 25%        0.000000 10731681.250000          414.000000           283.531894
# 50%        1.000000 21725643.000000          639.960000           415.220000
# 75%        1.000000 28452387.000000          969.920000           619.968500
# max        1.000000 46661804.000000        23294.220000          8485.035000
#
#        revenue_sum_std_7d  revenue_sum_sum_7d  revenue_sum_count_7d  \
# count       468552.000000       500000.000000         500000.000000
# mean           247.689393         1845.637883              4.064160
# std            219.980227         1483.067628              3.072057
# min              0.000000            1.000000              1.000000
# 25%            103.635579          900.940000              3.000000
# 50%            191.360307         1474.920000              3.000000
# 75%            328.324037         2352.820000              5.000000
# max          10584.037940        81094.770000            171.000000
#
#        items_count_max_7d  items_count_mean_7d  items_count_std_7d  \
# count       500000.000000        500000.000000       468552.000000
# mean             6.644806             4.448378            2.082372
# std              3.767259             2.400114            1.700930
# min              1.000000             1.000000            0.000000
# 25%              4.000000             2.750000            0.957427
# 50%              6.000000             4.000000            1.732051
# 75%              8.000000             5.666667            2.828427
# max            190.000000            54.000000           93.510695
#
#        items_count_sum_7d  revenue_sum_max_14d  revenue_sum_mean_14d  \
# count       500000.000000        500000.000000         500000.000000
# mean            17.171574           757.652491            494.607167
# std             13.900050           495.770731            317.598032
# min              1.000000             1.000000              1.000000
# 25%              8.000000           414.000000            283.531894
# 50%             14.000000           639.960000            415.220000
# 75%             22.000000           969.920000            619.968500
# max            667.000000         23294.220000           8485.035000
#
#        revenue_sum_std_14d  revenue_sum_sum_14d  revenue_sum_count_14d  \
# count        468552.000000        500000.000000          500000.000000
# mean            247.689393          1845.637883               4.064160
# std             219.980227          1483.067628               3.072057
# min               0.000000             1.000000               1.000000
# 25%             103.635579           900.940000               3.000000
# 50%             191.360307          1474.920000               3.000000
# 75%             328.324037          2352.820000               5.000000
# max           10584.037940         81094.770000             171.000000
#
#        items_count_max_14d  items_count_mean_14d  items_count_std_14d  \
# count        500000.000000         500000.000000        468552.000000
# mean              6.644806              4.448378             2.082372
# std               3.767259              2.400114             1.700930
# min               1.000000              1.000000             0.000000
# 25%               4.000000              2.750000             0.957427
# 50%               6.000000              4.000000             1.732051
# 75%               8.000000              5.666667             2.828427
# max             190.000000             54.000000            93.510695
#
#        items_count_sum_14d  revenue_sum_max_28d  revenue_sum_mean_28d  \
# count        500000.000000        500000.000000         500000.000000
# mean             17.171574           757.652491            494.607167
# std              13.900050           495.770731            317.598032
# min               1.000000             1.000000              1.000000
# 25%               8.000000           414.000000            283.531894
# 50%              14.000000           639.960000            415.220000
# 75%              22.000000           969.920000            619.968500
# max             667.000000         23294.220000           8485.035000
#
#        revenue_sum_std_28d  revenue_sum_sum_28d  revenue_sum_count_28d  \
# count        468552.000000        500000.000000          500000.000000
# mean            247.689393          1845.637883               4.064160
# std             219.980227          1483.067628               3.072057
# min               0.000000             1.000000               1.000000
# 25%             103.635579           900.940000               3.000000
# 50%             191.360307          1474.920000               3.000000
# 75%             328.324037          2352.820000               5.000000
# max           10584.037940         81094.770000             171.000000
#
#        items_count_max_28d  items_count_mean_28d  items_count_std_28d  \
# count        500000.000000         500000.000000        468552.000000
# mean              6.644806              4.448378             2.082372
# std               3.767259              2.400114             1.700930
# min               1.000000              1.000000             0.000000
# 25%               4.000000              2.750000             0.957427
# 50%               6.000000              4.000000             1.732051
# 75%               8.000000              5.666667             2.828427
# max             190.000000             54.000000            93.510695
#
#        items_count_sum_28d
# count        500000.000000
# mean             17.171574
# std              13.900050
# min               1.000000
# 25%               8.000000
# 50%              14.000000
# 75%              22.000000
# max             667.000000

# %%
df_windows_agg_test = calculate_window_features(df_test, ['customer_id', 'startdatetime'], windows)

# %%
df_windows_agg_test.describe()
# Out:
#           customer_id  revenue_sum_max_7d  revenue_sum_mean_7d  \
# count   112334.000000       112334.000000        112334.000000
# mean  20748611.321951          758.455421           495.420288
# std   11582578.505840          494.515099           316.901508
# min      52341.000000            1.000000             1.000000
# 25%   11041231.250000          409.990000           283.310000
# 50%   22155898.000000          639.950000           415.717500
# 75%   28861910.500000          969.970000           622.461875
# max   46668221.000000         8099.100000          5296.370000
#
#        revenue_sum_std_7d  revenue_sum_sum_7d  revenue_sum_count_7d  \
# count       105282.000000       112334.000000         112334.000000
# mean           252.123928         1780.666537              3.868366
# std            222.529589         1392.809678              2.725431
# min              0.000000            1.000000              1.000000
# 25%            104.905484          879.952500              3.000000
# 50%            194.858663         1434.920000              3.000000
# 75%            334.176288         2270.855000              4.000000
# max           5023.081513        47242.440000             98.000000
#
#        items_count_max_7d  items_count_mean_7d  items_count_std_7d  \
# count       112334.000000        112334.000000       105282.000000
# mean             6.565172             4.403679            2.084958
# std              3.725996             2.365839            1.701388
# min              1.000000             1.000000            0.000000
# 25%              4.000000             2.727273            0.957427
# 50%              6.000000             4.000000            1.732051
# 75%              8.000000             5.625000            2.828427
# max             92.000000            32.000000           51.384174
#
#        items_count_sum_7d  revenue_sum_max_14d  revenue_sum_mean_14d  \
# count       112334.000000        112334.000000         112334.000000
# mean            16.347491           758.455421            495.420288
# std             12.968391           494.515099            316.901508
# min              1.000000             1.000000              1.000000
# 25%              8.000000           409.990000            283.310000
# 50%             13.000000           639.950000            415.717500
# 75%             20.000000           969.970000            622.461875
# max            384.000000          8099.100000           5296.370000
#
#        revenue_sum_std_14d  revenue_sum_sum_14d  revenue_sum_count_14d  \
# count        105282.000000        112334.000000          112334.000000
# mean            252.123928          1780.666537               3.868366
# std             222.529589          1392.809678               2.725431
# min               0.000000             1.000000               1.000000
# 25%             104.905484           879.952500               3.000000
# 50%             194.858663          1434.920000               3.000000
# 75%             334.176288          2270.855000               4.000000
# max            5023.081513         47242.440000              98.000000
#
#        items_count_max_14d  items_count_mean_14d  items_count_std_14d  \
# count        112334.000000         112334.000000        105282.000000
# mean              6.565172              4.403679             2.084958
# std               3.725996              2.365839             1.701388
# min               1.000000              1.000000             0.000000
# 25%               4.000000              2.727273             0.957427
# 50%               6.000000              4.000000             1.732051
# 75%               8.000000              5.625000             2.828427
# max              92.000000             32.000000            51.384174
#
#        items_count_sum_14d  revenue_sum_max_28d  revenue_sum_mean_28d  \
# count        112334.000000        112334.000000         112334.000000
# mean             16.347491           758.455421            495.420288
# std              12.968391           494.515099            316.901508
# min               1.000000             1.000000              1.000000
# 25%               8.000000           409.990000            283.310000
# 50%              13.000000           639.950000            415.717500
# 75%              20.000000           969.970000            622.461875
# max             384.000000          8099.100000           5296.370000
#
#        revenue_sum_std_28d  revenue_sum_sum_28d  revenue_sum_count_28d  \
# count        105282.000000        112334.000000          112334.000000
# mean            252.123928          1780.666537               3.868366
# std             222.529589          1392.809678               2.725431
# min               0.000000             1.000000               1.000000
# 25%             104.905484           879.952500               3.000000
# 50%             194.858663          1434.920000               3.000000
# 75%             334.176288          2270.855000               4.000000
# max            5023.081513         47242.440000              98.000000
#
#        items_count_max_28d  items_count_mean_28d  items_count_std_28d  \
# count        112334.000000         112334.000000        105282.000000
# mean              6.565172              4.403679             2.084958
# std               3.725996              2.365839             1.701388
# min               1.000000              1.000000             0.000000
# 25%               4.000000              2.727273             0.957427
# 50%               6.000000              4.000000             1.732051
# 75%               8.000000              5.625000             2.828427
# max              92.000000             32.000000            51.384174
#
#        items_count_sum_28d
# count        112334.000000
# mean             16.347491
# std              12.968391
# min               1.000000
# 25%               8.000000
# 50%              13.000000
# 75%              20.000000
# max             384.000000

# %% [markdown]
# ### Information value
#
# IV < 0,02 — отсутствует;
#
# 0,02 ≤ IV <0,1 — низкая;
#
# 0,1 ≤ IV < 0,3 — средняя;
#
# IV ≥ 0,3 — высокая.

# %%
def calculate_information_value(dataset, feats, target_col):
    iv_by_feat = {}
    temp = dataset.copy()
    for feat in feats:
        temp["quant_range"] = pd.qcut(
            x=temp[feat], q=[0, 0.25, 0.5, 0.75, 1.0], duplicates="drop"
        )

        bins = {}
        for i, bin in enumerate(temp["quant_range"].unique()):
            bins[bin] = i

        temp["bin"] = temp["quant_range"].apply(lambda x: bins[x])

        iv = (
            pd.crosstab(temp["bin"], temp[target_col], normalize="columns")
            .assign(woe=lambda dfx: np.log(dfx[1] / dfx[0]))
            .assign(iv=lambda dfx: np.sum(dfx["woe"] * (dfx[1] - dfx[0])))
        )["iv"].unique()[0]

        iv_by_feat[feat] = [iv]
    df = pd.DataFrame(iv_by_feat).T
    df.reset_index(inplace=True)
    df.columns = ["feature", "IV"]
    return df

# %%
feats = list(set(df_windows_agg.columns).difference(ids_cols))

# %%
iv_df = calculate_information_value(df_windows_agg, feats, "buy_post")

# %%
iv_df.sort_values(by="IV", ascending=False)
# Out:
#                   feature       IV
# 3    revenue_sum_count_7d 0.155249
# 26  revenue_sum_count_14d 0.155249
# 13  revenue_sum_count_28d 0.155249
# 12    items_count_sum_14d 0.088741
# 16    items_count_sum_28d 0.088741
# 8      items_count_sum_7d 0.088741
# 23    revenue_sum_sum_28d 0.043770
# 5     revenue_sum_sum_14d 0.043770
# 0      revenue_sum_sum_7d 0.043770
# 19    items_count_max_28d 0.012120
# 20     items_count_max_7d 0.012120
# 17    items_count_max_14d 0.012120
# 25   items_count_mean_14d 0.008940
# 15    items_count_mean_7d 0.008940
# 21   items_count_mean_28d 0.008940
# 1     revenue_sum_std_14d 0.005667
# 2     revenue_sum_std_28d 0.005667
# 18     revenue_sum_std_7d 0.005667
# 6     items_count_std_28d 0.001754
# 24     items_count_std_7d 0.001754
# 7     items_count_std_14d 0.001754
# 10   revenue_sum_mean_28d 0.000737
# 14   revenue_sum_mean_14d 0.000737
# 11    revenue_sum_mean_7d 0.000737
# 4     revenue_sum_max_28d 0.000643
# 9      revenue_sum_max_7d 0.000643
# 22    revenue_sum_max_14d 0.000643
