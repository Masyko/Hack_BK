# %%
import pandas as pd
import numpy as np
import plotly.express as px
from sklearn.model_selection import train_test_split
import lightgbm
from sklearn.model_selection import KFold
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import GroupKFold
from sklearn.metrics import f1_score, roc_auc_score, classification_report, roc_curve, auc
from catboost import CatBoostClassifier
import time
import os
from sklearn.linear_model import LogisticRegression

# %%
from IPython.core.display import display, HTML, clear_output
display(HTML("<style>.container { width:85% !important; }</style>"))
display(HTML("<style>.prompt { min-width:10ex !important; }</style>"))
pd.set_option('display.max_rows', 1000)
pd.set_option('display.max_columns', 1000)
pd.set_option('display.float_format', lambda x: '%.6f' % x)
# Out:
# /tmp/ipykernel_55203/437858164.py:1: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML, clear_output
# /tmp/ipykernel_55203/437858164.py:1: DeprecationWarning: Importing clear_output from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML, clear_output
# <style>.container { width:85% !important; }</style>
# <style>.prompt { min-width:10ex !important; }</style>

# %%
df_with_feats = pd.read_parquet("../data/train_with_feats_v4.parquet")

# %%
df_train, df_val = train_test_split(df_with_feats, test_size=0.2, random_state=42, stratify=df_with_feats.buy_post)

# %%
information_value = pd.read_csv('../data/feature_information_value.csv', sep=';')

# %% [markdown]
# ### Feature selection

# %% [markdown]
# IV < 0,02 — отсутствует;
#
# 0,02 ≤ IV <0,1 — низкая;
#
# 0,1 ≤ IV < 0,3 — средняя;
#
#
# IV ≥ 0,3 — высокая.

# %%
best_iv_feats = information_value[information_value["IV"] >= 0.02].feature.values
len(best_iv_feats)
# Out:
# 42

# %%
information_value[information_value["IV"] >= 0.02].sort_values(by="IV", ascending=False)
# Out:
#                    feature       IV
# 62           receipt_count 0.430457
# 30            weekends_std 0.243150
# 69             strange_std 0.237534
# 47                 dom_std 0.161640
# 1    revenue_sum_count_14d 0.155249
# 65   revenue_sum_count_28d 0.155249
# 3     revenue_sum_count_7d 0.155249
# 35           was_promo_std 0.120205
# 46                 fun_sum 0.105191
# 88                 dow_std 0.097692
# 97      abs_sum_delta_mean 0.097432
# 15             was_rec_std 0.090511
# 95     items_count_sum_14d 0.088741
# 36     items_count_sum_28d 0.088741
# 14      items_count_sum_7d 0.088741
# 42            strange_mean 0.085361
# 84          sum_delta_mean 0.081003
# 72                dom_mean 0.078925
# 11         count_delta_max 0.078453
# 22        count_delta_mean 0.077059
# 101          sum_delta_max 0.065213
# 61          first_half_min 0.059577
# 76              dom_median 0.057772
# 18    abs_count_delta_mean 0.052973
# 48           weekends_mean 0.049743
# 96       cosine_similarity 0.047049
# 68     revenue_sum_sum_14d 0.043770
# 81     revenue_sum_sum_28d 0.043770
# 21      revenue_sum_sum_7d 0.043770
# 66             minutes_std 0.042768
# 33             minutes_var 0.042768
# 56         count_delta_min 0.037541
# 39          was_promo_mean 0.034826
# 9                    ratio 0.031495
# 54           sqm_place_sem 0.030976
# 75             minutes_sem 0.030169
# 20                    diff 0.027565
# 38           is_burger_std 0.027302
# 52                dow_mean 0.027288
# 93         count_delta_std 0.024725
# 17           sum_delta_min 0.021761
# 103                fun_std 0.021617

# %%
bad_feats = [
#     "items_count_sum_28d",
    "items_count_sum_14d", 
    "items_count_sum_7d", 
#     "revenue_sum_sum_28d",
    "minutes_var",
    "revenue_sum_count_14d",
    "minutes_sem",
    "revenue_sum_count_7d",
    "revenue_sum_count_28d",
    "revenue_sum_sum_14d",
    "revenue_sum_sum_7d",
    "dom_mean",
    "dow_mean",
    "count_delta_max",
    "count_delta_min",
#     "receipt_count", # or "revenue_sum_count_28d"
#     "sum_delta_min",
    "diff",
#     "receipt_count",
]

# %%
filtered_feats = [feat for feat in best_iv_feats if feat not in bad_feats]

# %%
len(best_iv_feats), len(filtered_feats)
# Out:
# (42, 28)

# %%
df_with_feats[filtered_feats].corr()
# Out:
#                          ratio  was_rec_std  sum_delta_min  \
# ratio                 1.000000     0.001247       0.050044
# was_rec_std           0.001247     1.000000      -0.132694
# sum_delta_min         0.050044    -0.132694       1.000000
# abs_count_delta_mean  0.064106     0.143807      -0.097017
# count_delta_mean      0.105682    -0.042153       0.290910
# weekends_std         -0.015628     0.013532       0.005617
# was_promo_std        -0.002875     0.012010      -0.114975
# items_count_sum_28d  -0.030231     0.173579      -0.254872
# is_burger_std        -0.001606     0.056725      -0.059257
# was_promo_mean        0.023254     0.281195      -0.009531
# strange_mean          0.001045     0.000510       0.008860
# fun_sum              -0.025240     0.227822      -0.192406
# dom_std              -0.013136     0.018437       0.000523
# weekends_mean         0.000626     0.004227      -0.042335
# sqm_place_sem         0.010636     0.051009       0.006747
# first_half_min       -0.075763     0.039630      -0.249984
# receipt_count        -0.035425     0.042288      -0.154225
# minutes_std          -0.007376     0.035032      -0.031075
# strange_std          -0.017780     0.018448      -0.003848
# dom_median           -0.007583    -0.006032      -0.000422
# revenue_sum_sum_28d  -0.026670     0.097527      -0.421090
# sum_delta_mean        0.137438    -0.025556       0.457197
# dow_std              -0.011372     0.019163      -0.009850
# count_delta_std       0.025034     0.245877      -0.432341
# cosine_similarity     0.010650    -0.318352       0.262895
# abs_sum_delta_mean    0.097386     0.064522      -0.260869
# sum_delta_max         0.065100     0.116443      -0.569947
# fun_std               0.006646     0.399342      -0.237493
#
#                       abs_count_delta_mean  count_delta_mean  weekends_std  \
# ratio                             0.064106          0.105682     -0.015628
# was_rec_std                       0.143807         -0.042153      0.013532
# sum_delta_min                    -0.097017          0.290910      0.005617
# abs_count_delta_mean              1.000000         -0.209659     -0.109304
# count_delta_mean                 -0.209659          1.000000      0.061222
# weekends_std                     -0.109304          0.061222      1.000000
# was_promo_std                    -0.002822         -0.008599     -0.009638
# items_count_sum_28d              -0.022484          0.057342      0.096426
# is_burger_std                     0.053714         -0.010551     -0.015241
# was_promo_mean                    0.111134         -0.019006      0.030400
# strange_mean                     -0.014290          0.010847      0.017621
# fun_sum                          -0.026710          0.002466      0.085393
# dom_std                          -0.083963          0.073296      0.123407
# weekends_mean                     0.042686         -0.014261     -0.402731
# sqm_place_sem                     0.076564          0.011270      0.021131
# first_half_min                    0.333880         -0.278280     -0.094134
# receipt_count                    -0.259641          0.039023      0.145124
# minutes_std                      -0.044673          0.046612      0.108026
# strange_std                      -0.102125          0.074599      0.124454
# dom_median                       -0.002662         -0.020832      0.000315
# revenue_sum_sum_28d              -0.048286          0.054557      0.068876
# sum_delta_mean                   -0.156260          0.674339      0.058942
# dow_std                          -0.076435          0.062019      0.721109
# count_delta_std                   0.315811         -0.064221     -0.039106
# cosine_similarity                -0.172100          0.031289     -0.029263
# abs_sum_delta_mean                0.592858         -0.162498     -0.115870
# sum_delta_max                    -0.026914          0.269005      0.040510
# fun_std                           0.362852         -0.077888     -0.009286
#
#                       was_promo_std  items_count_sum_28d  is_burger_std  \
# ratio                     -0.002875            -0.030231      -0.001606
# was_rec_std                0.012010             0.173579       0.056725
# sum_delta_min             -0.114975            -0.254872      -0.059257
# abs_count_delta_mean      -0.002822            -0.022484       0.053714
# count_delta_mean          -0.008599             0.057342      -0.010551
# weekends_std              -0.009638             0.096426      -0.015241
# was_promo_std              1.000000            -0.087444       0.107053
# items_count_sum_28d       -0.087444             1.000000       0.016220
# is_burger_std              0.107053             0.016220       1.000000
# was_promo_mean            -0.348331             0.276646       0.030969
# strange_mean              -0.008412             0.000933      -0.009361
# fun_sum                   -0.111039             0.683844      -0.047368
# dom_std                   -0.011026             0.083947      -0.004497
# weekends_mean              0.016672            -0.012977       0.017385
# sqm_place_sem              0.002841            -0.072516       0.003649
# first_half_min            -0.053799            -0.038557       0.055195
# receipt_count              0.059421             0.592967      -0.038086
# minutes_std                0.023944             0.055210      -0.005660
# strange_std               -0.012630             0.104242      -0.010993
# dom_median                -0.001743             0.012931       0.001582
# revenue_sum_sum_28d        0.040217             0.763619       0.039634
# sum_delta_mean            -0.017715             0.046471      -0.013664
# dow_std                   -0.004325             0.083464      -0.003565
# count_delta_std            0.033796             0.273168       0.057498
# cosine_similarity         -0.092363            -0.311486      -0.374932
# abs_sum_delta_mean         0.038319            -0.093643       0.059426
# sum_delta_max              0.104105             0.304499       0.050917
# fun_std                   -0.018946             0.302531       0.018397
#
#                       was_promo_mean  strange_mean   fun_sum   dom_std  \
# ratio                       0.023254      0.001045 -0.025240 -0.013136
# was_rec_std                 0.281195      0.000510  0.227822  0.018437
# sum_delta_min              -0.009531      0.008860 -0.192406  0.000523
# abs_count_delta_mean        0.111134     -0.014290 -0.026710 -0.083963
# count_delta_mean           -0.019006      0.010847  0.002466  0.073296
# weekends_std                0.030400      0.017621  0.085393  0.123407
# was_promo_std              -0.348331     -0.008412 -0.111039 -0.011026
# items_count_sum_28d         0.276646      0.000933  0.683844  0.083947
# is_burger_std               0.030969     -0.009361 -0.047368 -0.004497
# was_promo_mean              1.000000      0.008276  0.308759  0.035578
# strange_mean                0.008276      1.000000  0.005547 -0.396922
# fun_sum                     0.308759      0.005547  1.000000  0.074590
# dom_std                     0.035578     -0.396922  0.074590  1.000000
# weekends_mean              -0.011468     -0.025277 -0.015094 -0.009309
# sqm_place_sem               0.036319     -0.003330 -0.051722  0.032224
# first_half_min              0.036780     -0.011532 -0.061376 -0.037848
# receipt_count               0.018362      0.007884  0.523573  0.102578
# minutes_std                 0.007568     -0.000540  0.057793  0.077591
# strange_std                 0.035040     -0.063029  0.090244  0.342667
# dom_median                 -0.003511     -0.267253 -0.001581  0.000603
# revenue_sum_sum_28d         0.049035      0.000269  0.447139  0.076141
# sum_delta_mean             -0.004568      0.010612  0.016831  0.071269
# dow_std                     0.030789      0.001010  0.071212  0.140803
# count_delta_std             0.188375     -0.008822  0.215934 -0.017424
# cosine_similarity          -0.272385      0.012992 -0.256380 -0.054197
# abs_sum_delta_mean         -0.017564     -0.014089 -0.100043 -0.086528
# sum_delta_max               0.004952     -0.000510  0.212044  0.057802
# fun_std                     0.300159     -0.003656  0.487971  0.006359
#
#                       weekends_mean  sqm_place_sem  first_half_min  \
# ratio                      0.000626       0.010636       -0.075763
# was_rec_std                0.004227       0.051009        0.039630
# sum_delta_min             -0.042335       0.006747       -0.249984
# abs_count_delta_mean       0.042686       0.076564        0.333880
# count_delta_mean          -0.014261       0.011270       -0.278280
# weekends_std              -0.402731       0.021131       -0.094134
# was_promo_std              0.016672       0.002841       -0.053799
# items_count_sum_28d       -0.012977      -0.072516       -0.038557
# is_burger_std              0.017385       0.003649        0.055195
# was_promo_mean            -0.011468       0.036319        0.036780
# strange_mean              -0.025277      -0.003330       -0.011532
# fun_sum                   -0.015094      -0.051722       -0.061376
# dom_std                   -0.009309       0.032224       -0.037848
# weekends_mean              1.000000       0.006080        0.060052
# sqm_place_sem              0.006080       1.000000        0.032831
# first_half_min             0.060052       0.032831        1.000000
# receipt_count             -0.046030      -0.127058       -0.297778
# minutes_std               -0.016231       0.125553       -0.036431
# strange_std               -0.009675       0.015710       -0.053691
# dom_median                -0.004381      -0.005976        0.004594
# revenue_sum_sum_28d        0.015275      -0.075988        0.193283
# sum_delta_mean            -0.015149       0.011126       -0.440034
# dow_std                   -0.221848       0.051662       -0.058852
# count_delta_std            0.044139       0.054158        0.107625
# cosine_similarity         -0.020404      -0.058379       -0.140732
# abs_sum_delta_mean         0.055783       0.064917        0.517488
# sum_delta_max              0.032663       0.002826       -0.116362
# fun_std                    0.024690       0.046501        0.128943
#
#                       receipt_count  minutes_std  strange_std  dom_median  \
# ratio                     -0.035425    -0.007376    -0.017780   -0.007583
# was_rec_std                0.042288     0.035032     0.018448   -0.006032
# sum_delta_min             -0.154225    -0.031075    -0.003848   -0.000422
# abs_count_delta_mean      -0.259641    -0.044673    -0.102125   -0.002662
# count_delta_mean           0.039023     0.046612     0.074599   -0.020832
# weekends_std               0.145124     0.108026     0.124454    0.000315
# was_promo_std              0.059421     0.023944    -0.012630   -0.001743
# items_count_sum_28d        0.592967     0.055210     0.104242    0.012931
# is_burger_std             -0.038086    -0.005660    -0.010993    0.001582
# was_promo_mean             0.018362     0.007568     0.035040   -0.003511
# strange_mean               0.007884    -0.000540    -0.063029   -0.267253
# fun_sum                    0.523573     0.057793     0.090244   -0.001581
# dom_std                    0.102578     0.077591     0.342667    0.000603
# weekends_mean             -0.046030    -0.016231    -0.009675   -0.004381
# sqm_place_sem             -0.127058     0.125553     0.015710   -0.005976
# first_half_min            -0.297778    -0.036431    -0.053691    0.004594
# receipt_count              1.000000     0.079388     0.127101    0.007830
# minutes_std                0.079388     1.000000     0.076620    0.006306
# strange_std                0.127101     0.076620     1.000000   -0.014652
# dom_median                 0.007830     0.006306    -0.014652    1.000000
# revenue_sum_sum_28d        0.475606     0.068642     0.093719    0.009922
# sum_delta_mean             0.043744     0.043288     0.071395   -0.023695
# dow_std                    0.108888     0.137099     0.134014   -0.000929
# count_delta_std           -0.043944     0.001518    -0.023813   -0.015485
# cosine_similarity         -0.073738    -0.059111    -0.052390   -0.000277
# abs_sum_delta_mean        -0.255297    -0.034277    -0.105709   -0.001678
# sum_delta_max              0.192281     0.066857     0.061844   -0.020016
# fun_std                    0.004045     0.028026     0.003835   -0.012157
#
#                       revenue_sum_sum_28d  sum_delta_mean   dow_std  \
# ratio                           -0.026670        0.137438 -0.011372
# was_rec_std                      0.097527       -0.025556  0.019163
# sum_delta_min                   -0.421090        0.457197 -0.009850
# abs_count_delta_mean            -0.048286       -0.156260 -0.076435
# count_delta_mean                 0.054557        0.674339  0.062019
# weekends_std                     0.068876        0.058942  0.721109
# was_promo_std                    0.040217       -0.017715 -0.004325
# items_count_sum_28d              0.763619        0.046471  0.083464
# is_burger_std                    0.039634       -0.013664 -0.003565
# was_promo_mean                   0.049035       -0.004568  0.030789
# strange_mean                     0.000269        0.010612  0.001010
# fun_sum                          0.447139        0.016831  0.071212
# dom_std                          0.076141        0.071269  0.140803
# weekends_mean                    0.015275       -0.015149 -0.221848
# sqm_place_sem                   -0.075988        0.011126  0.051662
# first_half_min                   0.193283       -0.440034 -0.058852
# receipt_count                    0.475606        0.043744  0.108888
# minutes_std                      0.068642        0.043288  0.137099
# strange_std                      0.093719        0.071395  0.134014
# dom_median                       0.009922       -0.023695 -0.000929
# revenue_sum_sum_28d              1.000000        0.050592  0.067644
# sum_delta_mean                   0.050592        1.000000  0.059235
# dow_std                          0.067644        0.059235  1.000000
# count_delta_std                  0.156838       -0.042912 -0.008102
# cosine_similarity               -0.272067        0.025405 -0.045124
# abs_sum_delta_mean               0.070903       -0.248143 -0.080129
# sum_delta_max                    0.483928        0.382176  0.057269
# fun_std                          0.172464       -0.046108  0.007152
#
#                       count_delta_std  cosine_similarity  abs_sum_delta_mean  \
# ratio                        0.025034           0.010650            0.097386
# was_rec_std                  0.245877          -0.318352            0.064522
# sum_delta_min               -0.432341           0.262895           -0.260869
# abs_count_delta_mean         0.315811          -0.172100            0.592858
# count_delta_mean            -0.064221           0.031289           -0.162498
# weekends_std                -0.039106          -0.029263           -0.115870
# was_promo_std                0.033796          -0.092363            0.038319
# items_count_sum_28d          0.273168          -0.311486           -0.093643
# is_burger_std                0.057498          -0.374932            0.059426
# was_promo_mean               0.188375          -0.272385           -0.017564
# strange_mean                -0.008822           0.012992           -0.014089
# fun_sum                      0.215934          -0.256380           -0.100043
# dom_std                     -0.017424          -0.054197           -0.086528
# weekends_mean                0.044139          -0.020404            0.055783
# sqm_place_sem                0.054158          -0.058379            0.064917
# first_half_min               0.107625          -0.140732            0.517488
# receipt_count               -0.043944          -0.073738           -0.255297
# minutes_std                  0.001518          -0.059111           -0.034277
# strange_std                 -0.023813          -0.052390           -0.105709
# dom_median                  -0.015485          -0.000277           -0.001678
# revenue_sum_sum_28d          0.156838          -0.272067            0.070903
# sum_delta_mean              -0.042912           0.025405           -0.248143
# dow_std                     -0.008102          -0.045124           -0.080129
# count_delta_std              1.000000          -0.325302            0.174844
# cosine_similarity           -0.325302           1.000000           -0.119125
# abs_sum_delta_mean           0.174844          -0.119125            1.000000
# sum_delta_max                0.419075          -0.251843            0.060605
# fun_std                      0.524819          -0.370599            0.158549
#
#                       sum_delta_max   fun_std
# ratio                      0.065100  0.006646
# was_rec_std                0.116443  0.399342
# sum_delta_min             -0.569947 -0.237493
# abs_count_delta_mean      -0.026914  0.362852
# count_delta_mean           0.269005 -0.077888
# weekends_std               0.040510 -0.009286
# was_promo_std              0.104105 -0.018946
# items_count_sum_28d        0.304499  0.302531
# is_burger_std              0.050917  0.018397
# was_promo_mean             0.004952  0.300159
# strange_mean              -0.000510 -0.003656
# fun_sum                    0.212044  0.487971
# dom_std                    0.057802  0.006359
# weekends_mean              0.032663  0.024690
# sqm_place_sem              0.002826  0.046501
# first_half_min            -0.116362  0.128943
# receipt_count              0.192281  0.004045
# minutes_std                0.066857  0.028026
# strange_std                0.061844  0.003835
# dom_median                -0.020016 -0.012157
# revenue_sum_sum_28d        0.483928  0.172464
# sum_delta_mean             0.382176 -0.046108
# dow_std                    0.057269  0.007152
# count_delta_std            0.419075  0.524819
# cosine_similarity         -0.251843 -0.370599
# abs_sum_delta_mean         0.060605  0.158549
# sum_delta_max              1.000000  0.208178
# fun_std                    0.208178  1.000000

# %%
import plotly.io as pio

pio.renderers
pio.renderers.default = "png"

# %%
fig = px.imshow(df_with_feats[filtered_feats].corr())
fig.show()

# %% [markdown]
# ### Modeling

# %%
df_train["buy_post"].value_counts()
# Out:
# buy_post
# 1    287276
# 0    112724
# Name: count, dtype: int64

# %%
scale_pos_weight = 112724 / 287276

# %%
params = {
    'boosting_type': 'gbdt',
    'objective': 'binary',
    'metric': "binary",
    'num_leaves': 50,
    'max_depth': 20,
    'learning_rate': 0.15,
    'colsample_bytree': 0.8,
    'subsample': 0.8,
    'subsample_freq': 1,
    'n_jobs': 4,
    'n_estimators': 300,
    'scale_pos_weight': scale_pos_weight,
    'class_weight': None,
    'colsample_bytree': 0.8,
    'importance_type': 'gain',
    'min_child_samples': 50,
    'min_child_weight': 0.001,
    'min_split_gain': 0.0,
    'random_state': None,
    'reg_alpha': 0.0,
    'reg_lambda': 0.0,
    'subsample_for_bin': 200000,
}

# %%
current_feats = filtered_feats
len(current_feats)
# Out:
# 28

# %%
lgbm_model = lightgbm.LGBMModel(**params)

# %%
lgbm_model.fit(df_train[current_feats], df_train["buy_post"])
# Out:
# [LightGBM] [Info] Number of positive: 287276, number of negative: 112724
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.032435 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 5708
# [LightGBM] [Info] Number of data points in the train set: 400000, number of used features: 28
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.718190 -> initscore=0.935501
# [LightGBM] [Info] Start training from score 0.935501
# LGBMModel(colsample_bytree=0.8, importance_type='gain', learning_rate=0.15,
#           max_depth=20, metric='binary', min_child_samples=50, n_estimators=300,
#           n_jobs=4, num_leaves=50, objective='binary',
#           scale_pos_weight=0.3923892006293599, subsample=0.8, subsample_freq=1)

# %%
y_pred_lgbm = lgbm_model.predict(df_val[current_feats])

# %%
def with_cutoff(y_pred, cut_off):
    return [int(x > cut_off) for x in y_pred]

# %%
current_cut_off = 0.4

print(classification_report(df_val["buy_post"], with_cutoff(y_pred_lgbm, current_cut_off)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.47      0.46      0.47     28181
#            1       0.79      0.80      0.79     71819
#
#     accuracy                           0.70    100000
#    macro avg       0.63      0.63      0.63    100000
# weighted avg       0.70      0.70      0.70    100000

# %%
f1_score(df_val["buy_post"], with_cutoff(y_pred_lgbm, current_cut_off))
# Out:
# 0.7939644108363106

# %%
roc_auc_score(df_val["buy_post"], y_pred_lgbm)
# Out:
# 0.7143831381911884

# %%
fpr, tpr, thresholds = roc_curve(df_val["buy_post"], y_pred_lgbm)

# %%
fig = px.area(
    x=fpr, y=tpr,
    title=f'ROC Curve (AUC={auc(fpr, tpr):.4f})',
    labels=dict(x='False Positive Rate', y='True Positive Rate'),
    width=700, height=500
)
fig.add_shape(
    type='line', line=dict(dash='dash'),
    x0=0, x1=1, y0=0, y1=1
)

fig.update_yaxes(scaleanchor="x", scaleratio=1)
fig.update_xaxes(constrain='domain')
fig.show()

# %% [markdown]
# ### Test data

# %%
df_test = pd.read_parquet("../data/test_with_feats_v4.parquet")

# %%
y_test_pred = lgbm_model.predict(df_test[current_feats])

# %%
df_test["buy_post"] = with_cutoff(y_test_pred, current_cut_off)

# %%
df_test[["customer_id", "buy_post"]].describe()
# Out:
#           customer_id      buy_post
# count   112334.000000 112334.000000
# mean  20748611.321951      0.666753
# std   11582578.505840      0.471376
# min      52341.000000      0.000000
# 25%   11041231.250000      0.000000
# 50%   22155898.000000      1.000000
# 75%   28861910.500000      1.000000
# max   46668221.000000      1.000000

# %%
df_test[["customer_id", "buy_post"]].to_csv("test_pred_submission.csv", sep=';', index=False)
