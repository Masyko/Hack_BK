# %% [markdown]
# ### Гипотеза
#
# Посмотреть как то влияет ли средний чек или стандартное отклонение в рамках клиента на то уйдет ли он от БК или нет. Также посмотрим количество позиций в рамках одного чека.

# %%
import pandas as pd
import numpy as np
import plotly.express as px

# %%
from IPython.core.display import display, HTML, clear_output
display(HTML("<style>.container { width:85% !important; }</style>"))
display(HTML("<style>.prompt { min-width:10ex !important; }</style>"))
pd.set_option('display.max_rows', 1000)
pd.set_option('display.max_columns', 1000)
pd.set_option('display.float_format', lambda x: '%.6f' % x)
# Out:
# /tmp/ipykernel_117735/437858164.py:1: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML, clear_output
# /tmp/ipykernel_117735/437858164.py:1: DeprecationWarning: Importing clear_output from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML, clear_output
# <style>.container { width:85% !important; }</style>
# <style>.prompt { min-width:10ex !important; }</style>

# %%
df_train = pd.read_parquet('../data/train_dataset_hackaton2023_train.gzip')
df_test = pd.read_parquet('../data/hackaton2023_test.gzip')

# %%
df_train.describe()
# Out:
#           customer_id  date_diff_post        buy_post         revenue  \
# count 12129384.000000  9660867.000000 12129384.000000 12129384.000000
# mean  19809542.263361       20.480386        0.796485      106.799476
# min      29891.000000        0.000000        0.000000        0.010000
# 25%   10108525.000000        8.000000        1.000000       44.990000
# 50%   21274586.000000       17.000000        1.000000       79.980000
# 75%   28038562.000000       30.000000        1.000000      131.772500
# max   46661804.000000       60.000000        1.000000    14499.710000
# std   11389040.436254       15.270910        0.402613      107.438512
#
#                     startdatetime  ownareaall_sqm
# count                    12129384 12129384.000000
# mean   2023-02-20 12:19:13.394691      215.513003
# min           2022-09-02 00:00:39        0.000000
# 25%           2022-12-06 16:12:06      104.900000
# 50%           2023-02-22 11:04:22      210.400000
# 75%           2023-05-09 18:48:02      300.000000
# max           2023-08-01 23:57:46      978.700000
# std                           NaN      122.590689

# %%
def calculate_mean_std_feats(dataset, ids_cols):
    df_sum_agg = dataset.groupby(ids_cols, as_index=True).agg({"revenue": ["sum", "count"]})
    df_sum_agg.columns = ["revenue_sum", "items_count"]
    df_sum_agg.reset_index(inplace=True)
    new_ids_cols = list(set(ids_cols).difference(["startdatetime"]))
    df_by_customer_data = (
        df_sum_agg
        .groupby(new_ids_cols)
        .agg({
            "revenue_sum": ['mean', 'std', 'count'],
            "items_count": ['mean', 'std'],
        }).reset_index()
    )
    df_by_customer_data.columns = new_ids_cols + [
        'receipt_sum_mean', 
        'receipt_sum_std',
        'receipt_count', 
        'items_receipt_mean',
        'items_receipt_mean_std',
    ]
    return df_by_customer_data

# %%
df_train_processed = calculate_mean_std_feats(df_train, ["customer_id", "buy_post", "startdatetime"])
df_train_processed.describe()
# Out:
#           customer_id      buy_post  receipt_sum_mean  receipt_sum_std  \
# count   500000.000000 500000.000000     500000.000000    500000.000000
# mean  20246346.095608      0.718190        492.152797       259.144721
# std   11496610.350691      0.449882        295.469257       208.546239
# min      29891.000000      0.000000         13.497500         0.000000
# 25%   10731681.250000      0.000000        292.735000       121.704043
# 50%   21725643.000000      1.000000        419.995833       207.891439
# 75%   28452387.000000      1.000000        613.300000       338.487607
# max   46661804.000000      1.000000       5990.020000      9237.078619
#
#        receipt_count  items_receipt_mean  items_receipt_mean_std
# count  500000.000000       500000.000000           500000.000000
# mean        5.761172            4.420151                2.179619
# std         5.057282            2.199285                1.582691
# min         2.000000            1.000000                0.000000
# 25%         3.000000            2.846154                1.118034
# 50%         4.000000            4.000000                1.892969
# 75%         6.000000            5.600000                2.886751
# max       245.000000           49.750000               93.510695

# %%
df_test_processed = calculate_mean_std_feats(df_test, ["customer_id", "startdatetime"])
df_test_processed.describe()
# Out:
#           customer_id  receipt_sum_mean  receipt_sum_std  receipt_count  \
# count   112334.000000     112334.000000    112334.000000  112334.000000
# mean  20748611.321951        493.286188       262.211572       5.272429
# std   11582578.505840        295.966684       211.509668       4.396641
# min      52341.000000         24.392000         0.000000       2.000000
# 25%   11041231.250000        292.178000       120.921234       3.000000
# 50%   22155898.000000        421.269000       209.435801       4.000000
# 75%   28861910.500000        616.623333       342.937719       6.000000
# max   46668221.000000       5486.866667      3891.890319     148.000000
#
#        items_receipt_mean  items_receipt_mean_std
# count       112334.000000           112334.000000
# mean             4.379857                2.171851
# std              2.179753                1.592661
# min              1.000000                0.000000
# 25%              2.800000                1.070607
# 50%              4.000000                1.864454
# 75%              5.500000                2.886751
# max             30.666667               51.384174

# %% [markdown]
# ### Information value
#
# IV < 0,02 — отсутствует;
#
# 0,02 ≤ IV <0,1 — низкая;
#
# 0,1 ≤ IV < 0,3 — средняя;
#
# IV ≥ 0,3 — высокая.

# %%
def calculate_information_value(dataset, feats, target_col):
    iv_by_feat = {}
    temp = dataset.copy()
    for feat in feats:
        temp["quant_range"] = pd.qcut(
            x=temp[feat], q=[0, 0.25, 0.5, 0.75, 1.0], duplicates="drop"
        )

        bins = {}
        for i, bin in enumerate(temp["quant_range"].unique()):
            bins[bin] = i

        temp["bin"] = temp["quant_range"].apply(lambda x: bins[x])

        iv = (
            pd.crosstab(temp["bin"], temp[target_col], normalize="columns")
            .assign(woe=lambda dfx: np.log(dfx[1] / dfx[0]))
            .assign(iv=lambda dfx: np.sum(dfx["woe"] * (dfx[1] - dfx[0])))
        )["iv"].unique()[0]

        iv_by_feat[feat] = [iv]
    df = pd.DataFrame(iv_by_feat).T
    df.reset_index(inplace=True)
    df.columns = ["feature", "IV"]
    return df

# %%
df_train_processed.columns
# Out:
# Index(['customer_id', 'buy_post', 'receipt_sum_mean', 'receipt_sum_std',
#        'receipt_count', 'items_receipt_mean', 'items_receipt_mean_std'],
#       dtype='object')

# %%
feats = [
    'receipt_sum_mean', 
    'receipt_sum_std',
    'receipt_count', 
    'items_receipt_mean',
    'items_receipt_mean_std',
]

# %%
iv_df = calculate_information_value(df_train_processed, feats, "buy_post")

# %%
iv_df.sort_values(by="IV", ascending=False)
# Out:
#                   feature       IV
# 2           receipt_count 0.430457
# 3      items_receipt_mean 0.008995
# 1         receipt_sum_std 0.006076
# 4  items_receipt_mean_std 0.004762
# 0        receipt_sum_mean 0.001557
